# %%
import random

random_list = [random.random() for _ in range(5_000_000)]

print("Random list lenght:", len(random_list))
# Out:
# Random list lenght: 5000000

# %%
def mean_custom(values):
    sum = 0
    for val in values:
        sum += val
    return sum/len(values)

def st_deviation(values):
    sd = 0
    mean_val = mean_custom(values)
    for val in values:
        sd += (val - mean_val)**2
    sd = sd / len(values)
    return sd ** 0.5

# %%
print(f'Std: {st_deviation(random_list)}')
# Out:
# Std: 0.28869478174620244

# %%
import numpy as np

np_array = np.array(random_list, dtype=np.float64)

print(f'Std: {np_array.std()}')
# Out:
# Std: 0.2886947817461876
